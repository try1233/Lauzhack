# %%
import pandas as pd

# Specify the file path of the dataset
file_path = 'data/Amazon_Unlocked_Mobile.csv'

# Read the dataset into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#                                                                                                      Product Name  \
# 0       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D700*FRONT CAMERA*ANDROID*SLIDER*QWERTY KEYBOARD*TOUCH SCREEN
# 1       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D700*FRONT CAMERA*ANDROID*SLIDER*QWERTY KEYBOARD*TOUCH SCREEN
# 2       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D700*FRONT CAMERA*ANDROID*SLIDER*QWERTY KEYBOARD*TOUCH SCREEN
# 3       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D700*FRONT CAMERA*ANDROID*SLIDER*QWERTY KEYBOARD*TOUCH SCREEN
# 4       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D700*FRONT CAMERA*ANDROID*SLIDER*QWERTY KEYBOARD*TOUCH SCREEN
# ...                                                                                                           ...
# 413835                      Samsung Convoy U640 Phone for Verizon Wireless Network with No Contract (Gray) Rugged
# ...

# %%
df['Combined Info'] = df['Brand Name'] + ' ' + df['Product Name'] + ' Price:' + df['Price'].astype(str) + ' Review: ' + df['Reviews']

# %%
import matplotlib.pyplot as plt

plot = df['Product Name'].value_counts().head(200).plot(kind='bar')
plot.set_xticklabels(['Item {}'.format(i+1) for i in range(200)])
plot.set_xticks(range(0, 200, 25))

plt.show()
